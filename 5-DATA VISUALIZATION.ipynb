# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# !git clone https://github.com/AshishJangra27/datasets
# Out:
# Cloning into 'datasets'...
# remote: Enumerating objects: 328, done.
# remote: Counting objects: 100% (93/93), done.
# remote: Compressing objects: 100% (83/83), done.
# remote: Total 328 (delta 19), reused 54 (delta 9), pack-reused 235
# Receiving objects: 100% (328/328), 278.62 MiB | 15.36 MiB/s, done.
# Resolving deltas: 100% (145/145), done.
# Updating files: 100% (225/225), done.

# %%
df =pd.read_csv('datasets/Gaana/songs.csv')
df
# Out:
#                                                     name  \
# 0                                  Dil - E - Nadan Tujhe
# 1                      Agar Hum Kahen Aur Woh Muskara De
# 2                                          Unke Dekhe Se
# 3                Yeh Na Thi Hamari Qismat - Chitra Singh
# 4                                Hazaron Khwahishen Aisi
# ...                                                  ...
# 41350  Chaaridike Paaper Andhar (Manush Janam Diye Bi...
# 41351                                Ei Ki Go Shesh Daan
# 41352                                       Ei Je Bangla
# 41353                               Jatone Hridaye Rekho
# 41354                            Tomar Je Oi Haater Mala
#
#                                singer  \
# 0           Chitra Singh|Jagjit Singh
# 1           Chitra Singh|Jagjit Singh
# 2                        Jagjit Singh
# 3                        Chitra Singh
# 4                        Jagjit Singh
# ...                               ...
# ...

# %%
df.head()
# Out:
#                                       name                     singer  \
# 0                    Dil - E - Nadan Tujhe  Chitra Singh|Jagjit Singh
# 1        Agar Hum Kahen Aur Woh Muskara De  Chitra Singh|Jagjit Singh
# 2                            Unke Dekhe Se               Jagjit Singh
# 3  Yeh Na Thi Hamari Qismat - Chitra Singh               Chitra Singh
# 4                  Hazaron Khwahishen Aisi               Jagjit Singh
#
#                                       singer_id duration  \
# 0  /artist/chitra-singh|/artist/jagjeet-singh-1    05:00
# 1  /artist/chitra-singh|/artist/jagjeet-singh-1    06:26
# 2                       /artist/jagjeet-singh-1    03:41
# 3                          /artist/chitra-singh    04:26
# 4                       /artist/jagjeet-singh-1    05:39
#
#                                   link language
# 0                 /dil-e-nadan-tujhe-3     Urdu
# 1  /agar-hum-kahen-aur-woh-muskura-den     Urdu
# 2                       /unke-dekhe-se     Urdu
# ...

# %%
df.tail()
# Out:
#                                                     name  \
# 41350  Chaaridike Paaper Andhar (Manush Janam Diye Bi...
# 41351                                Ei Ki Go Shesh Daan
# 41352                                       Ei Je Bangla
# 41353                               Jatone Hridaye Rekho
# 41354                            Tomar Je Oi Haater Mala
#
#                                singer  \
# 41350                   Kishore Kumar
# 41351                    Feroza Begum
# 41352  Sandhya Mukherjee|Hemant Kumar
# 41353                Ajoy Chakrabarty
# 41354                     Asha Bhosle
#
#                                                singer_id duration  \
# 41350                              /artist/kishore-kumar    03:23
# 41351                               /artist/feroza-begum    03:56
# 41352  /artist/sandhya-mukherjee|/artist/hemanta-mukh...    07:36
# 41353                           /artist/ajoy-chakrabarty    04:29
# ...

# %%
df.columns
# Out:
# Index(['name', 'singer', 'singer_id', 'duration', 'link', 'language'], dtype='object')

# %%
songs = df.values
songs[4]
# Out:
# array(['Hazaron Khwahishen Aisi', 'Jagjit Singh',
#        '/artist/jagjeet-singh-1', '05:39', '/hazaron-khwahishen-aisi-1',
#        'Urdu'], dtype=object)

# %% [markdown]
# #### 1- Exploratory data analysis

# %% [markdown]
# #### 1.1- Checking Null Values

# %%
df.isnull().sum()
# Out:
# name         0
# singer       0
# singer_id    0
# duration     0
# link         0
# language     0
# dtype: int64

# %% [markdown]
# #### 1.2- Checking duplicates values

# %%
df =df.drop_duplicates()

# %%
df
# Out:
#                                                     name  \
# 0                                  Dil - E - Nadan Tujhe
# 1                      Agar Hum Kahen Aur Woh Muskara De
# 2                                          Unke Dekhe Se
# 3                Yeh Na Thi Hamari Qismat - Chitra Singh
# 4                                Hazaron Khwahishen Aisi
# ...                                                  ...
# 41350  Chaaridike Paaper Andhar (Manush Janam Diye Bi...
# 41351                                Ei Ki Go Shesh Daan
# 41352                                       Ei Je Bangla
# 41353                               Jatone Hridaye Rekho
# 41354                            Tomar Je Oi Haater Mala
#
#                                singer  \
# 0           Chitra Singh|Jagjit Singh
# 1           Chitra Singh|Jagjit Singh
# 2                        Jagjit Singh
# 3                        Chitra Singh
# 4                        Jagjit Singh
# ...                               ...
# ...

# %%
c = 0

for song in songs:
  if(song[1] == 'Jagjit Singh'):
    c += 1

print(c)
# Out:
# 172

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 41354 entries, 0 to 41354
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   name       41354 non-null  object
#  1   singer     41354 non-null  object
#  2   singer_id  41354 non-null  object
#  3   duration   41354 non-null  object
#  4   link       41354 non-null  object
#  5   language   41354 non-null  object
# dtypes: object(6)
# memory usage: 2.2+ MB

# %%
sub = 'Singh'

string = 'Chitra Singh|Jagjit Singh'

for i in range(len(string) - len(sub)-1):
  if string[i:i+len(sub)] == sub:
    print(True)
# Out:
# True

# %%
c= 0
for i in df['singer_id']:
  if 'jagjeet-singh-1' in i:
    c+=1
print(c)
# Out:
# 255

# %% [markdown]
# #### 1.3- Exploring Name column

# %%
df['name'].nunique()
# Out:
# 31534

# %%
df['name'].value_counts()
# Out:
# name
# O Mere Dil Ke Chain               26
# Hamen Tumse Pyar Kitna            22
# Padhyams                          20
# Chura Liya Hai Tumne Jo Dil Ko    18
# Yeh Sham Mastani                  18
#                                   ..
# Pundaleekanigaagi                  1
# Naa Hutti Beledaadu                1
# Kempu Roja Mogadavale              1
# Indhe Savi Samaya                  1
# Tomar Je Oi Haater Mala            1
# Name: count, Length: 31534, dtype: int64

# %% [markdown]
# #### 1.4- Exploring singer column
# - remove '|' operator

# %%
df['singer'].nunique()
# Out:
# 6196

# %%
df['singer'].value_counts()
# Out:
# singer
# Lata Mangeshkar                            1410
# Asha Bhosle                                1274
# Kishore Kumar                              1213
# Mohammed Rafi                              1201
# S. P. Balasubrahmanyam                     1164
#                                            ...
# Jamuna Rani|P. Susheela|P.B. Sreenivas        1
# M.S. Rajeswari|L.R. Eswari                    1
# K J Yesudas|Uma Ramanan                       1
# L.R. Eswari|P Suhseela|T M S Selvakumar       1
# Rabindranath Tagore                           1
# Name: count, Length: 6196, dtype: int64

# %% [markdown]
# ####1.5- Exploring singer_id column
# - remove '/artist/'

# %%
df['singer_id'].nunique()
# Out:
# 6580

# %%
df['singer_id'].value_counts()
# Out:
# singer_id
# /artist/lata-mangeshkar                                                                                                   1410
# /artist/asha-bhosle-1                                                                                                     1274
# /artist/kishore-kumar                                                                                                     1213
# /artist/mohammad-rafi                                                                                                     1201
# /artist/s-p-balasubrahamanyam                                                                                             1168
#                                                                                                                           ...
# /artist/padma-subrahmaniam|/artist/shyamala-balakrishnan|/artist/ks-vasudevan-21|/artist/n-vasudevan-22|/artist/chorus       1
# ...

# %% [markdown]
# #### Exploring duration column
# - convert it into seconds

# %%
df['duration'].nunique()
# Out:
# 1309

# %%
df['duration'].value_counts()
# Out:
# duration
# 03:02    447
# 03:21    408
# 04:00    403
# 05:00    384
# 03:03    384
#         ...
# 25:01      1
# 16:38      1
# 12:45      1
# 11:53      1
# 29:18      1
# Name: count, Length: 1309, dtype: int64

# %% [markdown]
# #### 1.7- Exploring link column

# %%
df['link'].nunique()
# Out:
# 36361

# %%
df['link'].value_counts()
# Out:
# link
# /kya-khoob-lagti-ho                   2
# /chanda-chhore-chandni                2
# /girdhari-chhed-muraliya-pyari        2
# /jab-se-tumhen-dekha-hai              2
# /dil-ka-bhanwar-kare-pukar-7          2
#                                      ..
# /shiva-ninnalli                       1
# /hennu-aadidaga                       1
# /jagadaadi-devatheya-prati-roopavo    1
# /chandiye                             1
# /tomar-je-oi-haater-mala              1
# Name: count, Length: 36361, dtype: int64

# %%
len(df[df['duration']== '05:00'])
# Out:
# 384

# %%
df[df['language']== 'Urdu']
# Out:
#                                          name                         singer  \
# 0                       Dil - E - Nadan Tujhe      Chitra Singh|Jagjit Singh
# 1           Agar Hum Kahen Aur Woh Muskara De      Chitra Singh|Jagjit Singh
# 2                               Unke Dekhe Se                   Jagjit Singh
# 3     Yeh Na Thi Hamari Qismat - Chitra Singh                   Chitra Singh
# 4                     Hazaron Khwahishen Aisi                   Jagjit Singh
# ...                                       ...                            ...
# 3111                                    Salam                   Farhat Shuja
# 3112      Thumri Tilang - Sajia Akeli Dukh De  Badar Uz Zaman|Qamar Uz Zaman
# 3113                        Sanwar Sanwar Kar                 Mumtaz Shirazi
# 3114                        Jo Teri Sana Mein                Muzaffar Warisi
# 3115             Lucky Seven & Lucky Thirteen            Karim Shahab ud Din
#
# ...

# %%
len(df[df['duration'] > '05:00'])
# Out:
# 13046

# %%
df[df['link']== '/kya-khoob-lagti-ho']
# Out:
#                      name          singer                       singer_id  \
# 18180  Kya Khoob Lagti Ho  Kanchan|Mukesh  /artist/kanchan|/artist/mukesh
# 23173  Kya Khoob Lagti Ho  Kanchan|Mukesh  /artist/kanchan|/artist/mukesh
#
#       duration                 link language
# 18180    03:59  /kya-khoob-lagti-ho    Hindi
# 23173    03:59  /kya-khoob-lagti-ho      Old

# %% [markdown]
# ####1.8- Exploring language column
# - remove 'old' category in language column

# %%
df['language'].unique()
# Out:
# array(['Urdu', 'Gujarati', 'Tamil', 'Kannada', 'Rajasthani', 'Haryanvi',
#        'Punjabi', 'Hindi', 'Old', 'Malayalam', 'Marathi', 'Telugu',
#        'Odia', 'Bhojpuri', 'Assamese', 'Bengali'], dtype=object)

# %%
df['language'].nunique()
# Out:
# 16

# %%
df['language'].value_counts()
# Out:
# language
# Telugu        4995
# Hindi         4993
# Old           4993
# Marathi       4699
# Tamil         4677
# Punjabi       3818
# Kannada       3559
# Urdu          3116
# Gujarati      2115
# Bengali        958
# Odia           940
# Assamese       724
# Rajasthani     541
# Bhojpuri       519
# Malayalam      479
# Haryanvi       228
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#                        name           singer                singer_id  \
# count                 41354            41354                    41354
# unique                31534             6196                     6580
# top     O Mere Dil Ke Chain  Lata Mangeshkar  /artist/lata-mangeshkar
# freq                     26             1410                     1410
#
#        duration                 link language
# count     41354                41354    41354
# unique     1309                36361       16
# top       03:02  /kya-khoob-lagti-ho   Telugu
# freq        447                    2     4995

# %% [markdown]
# ### 2- Data Cleaning

# %% [markdown]
# ####2.1- Remove the duplicates values as per language.

# %%
len(df[df['language'] != 'Old']['link'])
# Out:
# 36361

# %%
df[df['language'] != 'Old']['link'].nunique()
# Out:
# 36361

# %%
df = df[df['language'] != 'Old']

# %%
df
# Out:
#                                                     name  \
# 0                                  Dil - E - Nadan Tujhe
# 1                      Agar Hum Kahen Aur Woh Muskara De
# 2                                          Unke Dekhe Se
# 3                Yeh Na Thi Hamari Qismat - Chitra Singh
# 4                                Hazaron Khwahishen Aisi
# ...                                                  ...
# 41350  Chaaridike Paaper Andhar (Manush Janam Diye Bi...
# 41351                                Ei Ki Go Shesh Daan
# 41352                                       Ei Je Bangla
# 41353                               Jatone Hridaye Rekho
# 41354                            Tomar Je Oi Haater Mala
#
#                                singer  \
# 0           Chitra Singh|Jagjit Singh
# 1           Chitra Singh|Jagjit Singh
# 2                        Jagjit Singh
# 3                        Chitra Singh
# 4                        Jagjit Singh
# ...                               ...
# ...

# %%
df.reset_index()
# Out:
#        index                                               name  \
# 0          0                              Dil - E - Nadan Tujhe
# 1          1                  Agar Hum Kahen Aur Woh Muskara De
# 2          2                                      Unke Dekhe Se
# 3          3            Yeh Na Thi Hamari Qismat - Chitra Singh
# 4          4                            Hazaron Khwahishen Aisi
# ...      ...                                                ...
# 36356  41350  Chaaridike Paaper Andhar (Manush Janam Diye Bi...
# 36357  41351                                Ei Ki Go Shesh Daan
# 36358  41352                                       Ei Je Bangla
# 36359  41353                               Jatone Hridaye Rekho
# 36360  41354                            Tomar Je Oi Haater Mala
#
#                                singer  \
# 0           Chitra Singh|Jagjit Singh
# 1           Chitra Singh|Jagjit Singh
# 2                        Jagjit Singh
# 3                        Chitra Singh
# ...

# %% [markdown]
# ####2.2- Convert duration column into seconds.

# %%
for i in df['duration'][:10]:
  lst = i.split(':')
  print(i,int(lst[0])*60 + int(lst[1]) )
# Out:
# 05:00 300
# 06:26 386
# 03:41 221
# 04:26 266
# 05:39 339
# 07:59 479
# 04:48 288
# 05:21 321
# 03:09 189
# 04:24 264

# %% [markdown]
# #### Add into dataset.

# %%
duration =[]
for i in df['duration']:
  lst = i.split(':')
  if (len(lst))== 2:
   duration.append(int(lst[0])*60 +int(lst[1]))
  else:
    duration.append(int(lst[0])*60*60 +int(lst[1])*60 +int(lst[2]))

#print(durations)
df['duration']= duration
# Out:
# <ipython-input-39-965d6b8ff72f>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['duration']= duration

# %%
df
# Out:
#                                                     name  \
# 0                                  Dil - E - Nadan Tujhe
# 1                      Agar Hum Kahen Aur Woh Muskara De
# 2                                          Unke Dekhe Se
# 3                Yeh Na Thi Hamari Qismat - Chitra Singh
# 4                                Hazaron Khwahishen Aisi
# ...                                                  ...
# 41350  Chaaridike Paaper Andhar (Manush Janam Diye Bi...
# 41351                                Ei Ki Go Shesh Daan
# 41352                                       Ei Je Bangla
# 41353                               Jatone Hridaye Rekho
# 41354                            Tomar Je Oi Haater Mala
#
#                                singer  \
# 0           Chitra Singh|Jagjit Singh
# 1           Chitra Singh|Jagjit Singh
# 2                        Jagjit Singh
# 3                        Chitra Singh
# 4                        Jagjit Singh
# ...                               ...
# ...

# %%
max(df['duration'])
# Out:
# 25680

# %%
min(df['duration'])
# Out:
# 17

# %% [markdown]
# ####2.3- Remove '/artist/' into singer_id column.

# %%
df['singer_id'] = df['singer_id'].str.replace('/artist/','').str.replace('|',',')
df.head()
# Out:
# <ipython-input-43-eab2ec78fc3e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['singer_id'] = df['singer_id'].str.replace('/artist/','').str.replace('|',',')
#                                       name                     singer  \
# 0                    Dil - E - Nadan Tujhe  Chitra Singh|Jagjit Singh
# 1        Agar Hum Kahen Aur Woh Muskara De  Chitra Singh|Jagjit Singh
# 2                            Unke Dekhe Se               Jagjit Singh
# 3  Yeh Na Thi Hamari Qismat - Chitra Singh               Chitra Singh
# 4                  Hazaron Khwahishen Aisi               Jagjit Singh
#
#                       singer_id  duration  \
# 0  chitra-singh,jagjeet-singh-1       300
# 1  chitra-singh,jagjeet-singh-1       386
# ...

# %% [markdown]
# ####2.4-  Remove '|' operator in singer column.

# %%
df['singer'] = df['singer'].str.replace('|', ',')
df.head()
# Out:
# <ipython-input-44-78238a10c16a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['singer'] = df['singer'].str.replace('|', ',')
#                                       name                     singer  \
# 0                    Dil - E - Nadan Tujhe  Chitra Singh,Jagjit Singh
# 1        Agar Hum Kahen Aur Woh Muskara De  Chitra Singh,Jagjit Singh
# 2                            Unke Dekhe Se               Jagjit Singh
# 3  Yeh Na Thi Hamari Qismat - Chitra Singh               Chitra Singh
# 4                  Hazaron Khwahishen Aisi               Jagjit Singh
#
#                       singer_id  duration  \
# 0  chitra-singh,jagjeet-singh-1       300
# 1  chitra-singh,jagjeet-singh-1       386
# ...

# %% [markdown]
# ####2.5-  Remove '/' operator in link column.

# %%
df['link'] = df['link'].str.replace('/','')
df.head()
# Out:
# <ipython-input-45-b514c87c177e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['link'] = df['link'].str.replace('/','')
#                                       name                     singer  \
# 0                    Dil - E - Nadan Tujhe  Chitra Singh,Jagjit Singh
# 1        Agar Hum Kahen Aur Woh Muskara De  Chitra Singh,Jagjit Singh
# 2                            Unke Dekhe Se               Jagjit Singh
# 3  Yeh Na Thi Hamari Qismat - Chitra Singh               Chitra Singh
# 4                  Hazaron Khwahishen Aisi               Jagjit Singh
#
#                       singer_id  duration                                link  \
# 0  chitra-singh,jagjeet-singh-1       300                 dil-e-nadan-tujhe-3
# ...

# %% [markdown]
# ### 3- Data Analysis

# %% [markdown]
# #### Save the dataset

# %%
df.to_csv('songsclean.csv')

# %%
cool_palette = ['#3498db', '#95a5a6', '#2ecc71', '#ecf0f1']

sns.set_palette(cool_palette)

# %% [markdown]
# #### 3.1- find the number of unique singers.

# %%
lst =[]
for i in df['singer_id']:
  lst.extend(i.split(','))
print(len(set(lst)))

df['singer_id'].str.split(',').explode().nunique()

len(list(set(','.join(df['singer_id']).split(','))))
# Out:
# 4528
# 4528

# %%
#lst =[]
for m in range(len(lst))[:10]:
 c= 0
 for i in df['singer_id']:
  if (lst[m] in i):
    c+=1
 print(lst[m],c)
# Out:
# chitra-singh 87
# jagjeet-singh-1 184
# chitra-singh 87
# jagjeet-singh-1 184
# jagjeet-singh-1 184
# chitra-singh 87
# jagjeet-singh-1 184
# chitra-singh 87
# jagjeet-singh-1 184
# chitra-singh 87

# %% [markdown]
# ####3.2- Top 10 singers who have sang max no. of songs.

# %%
from tqdm import tqdm

singers = list(set(lst))

singer_lst = []

for singer in tqdm(singers):            # Going through every singer
  c = 0
  for i in df['singer_id']:       # Counting number of songs for each singer
    if (singer in i.split(',')):
      c += 1

  singer_lst.append([singer,c])

singer_df = pd.DataFrame(singer_lst, columns = ['singer','count'])

singer_df.sort_values(by = 'count', ascending = False).head(10)
# Out:
# 100%|██████████| 4528/4528 [01:09<00:00, 65.38it/s]
#                      singer  count
# 2258  s-p-balasubrahamanyam   3617
# 15              p-suseela-2   3212
# 4427               s-janaki   2193
# 2147          asha-bhosle-1   1981
# 2431        lata-mangeshkar   1726
# 2286          kishore-kumar   1281
# 1407          mohammad-rafi   1223
# 1602            ghanatasala   1109
# 1527                 chorus   1108
# 1105           pb-sreenivas    937

# %%
singer_df= singer_df.sort_values(by = 'count', ascending = False)
singer_df =singer_df.head(10)

# %%
singer_df.to_csv("singer_df.csv", index =False)

# %% [markdown]
# ####3.3- Top 10 Longest Songs as per Duration.

# %%
longest_songs = df.sort_values(by = 'duration' , ascending = False).head(10)
longest_songs
# Out:
#                                name          singer       singer_id  duration  \
# 16093                    Haye Tumba  Dilshad Akhtar  dilshad-akhtar     25680
# 16352                Bum Bum Lahiri  Dilshad Akhtar  dilshad-akhtar     24720
# 15000                Bum Bum Lahiri  Dilshad Akhtar  dilshad-akhtar     24720
# 15025          Kanu Atharu Bahoundi  Dilshad Akhtar  dilshad-akhtar     21840
# 14624  Desi Bandri Vilayati Cheekan  Dilshad Akhtar  dilshad-akhtar     21780
# 16022  Desi Bandri Vilayati Cheekan  Dilshad Akhtar  dilshad-akhtar     21780
# 15259        Kunda Khol Basantariye  Dilshad Akhtar  dilshad-akhtar     21720
# 16027                 Ghund Kad Lai  Dilshad Akhtar  dilshad-akhtar     20880
# 14655                 Ghund Kad Lai  Dilshad Akhtar  dilshad-akhtar     20880
# 14360               Man Wich Vasnai  Dilshad Akhtar  dilshad-akhtar     20580
#
#                                  link language
# 16093                      haye-tumba  Punjabi
# ...

# %% [markdown]
# ####3.4-  Finding the Punjabi Songs with duration between 3 to 4 minutes

# %%
punjabi_songs = df[(df['language'] == 'Punjabi') & (df['duration']>=180) & (df['duration'] <=240)].head(10)
punjabi_songs
# Out:
#                                                 name  \
# 14236                             Pehle Lalkare Naal
# 14244                                 Dat Khol Mitra
# 14245                      Bhul Gai Main Ghund Kadna
# 14246                     Bach Ke Reha Kar Tun Nakro
# 14247                  Kaali Teri Gut - Punjabi Geet
# 14250  Chand Kithe Gujari Ai Raat - Punjabi Lok Geet
# 14251                               Aa Mundiya Ve Tu
# 14253                               Gabroo Ho Len De
# 14255                          Put Bana Ke Chhadange
# 14257                                  Juthi Qasoori
#
#                             singer                    singer_id  duration  \
# 14236  Amar Singh Chamkila,Amarjot  amar-singh-chamkila,amarjot       211
# 14244  Amar Singh Chamkila,Amarjot  amar-singh-chamkila,amarjot       197
# 14245  Amar Singh Chamkila,Amarjot  amar-singh-chamkila,amarjot       214
# 14246  Amar Singh Chamkila,Amarjot  amar-singh-chamkila,amarjot       239
# ...

# %% [markdown]
# ####3.5- Which song in the dataset has the highest number of collaborating artists?

# %%
df['singers'] = df['singer'].str.split(',').str.len()
df.sort_values(by ='singers', ascending = False ).head(10)
# Out:
# <ipython-input-55-b50330c775b6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['singers'] = df['singer'].str.split(',').str.len()
#                                           name  \
# 41048  Neel Kamal Lal Kamal - Thakurmaar Jhuli
# 16506                           Ungla Te Munde
# 16124                    Mere Viah La Babla Ve
# 16069                    Charkhe Di Tand Warga
# 14958                       Ag To Buja De Illo
# 15668                           Main Akh Maari
# 15685                      Ley Chail Ve Mittra
# 16026                  Saali Wekh Patole Vargi
# 15711             Baaba Ho Laa Ke Bhabi Laa Ra
# 15882                    Chunni Thalle Ambiaan
#
#                                                   singer  \
# ...

# %%
df[df['language'] == 'Urdu'].sort_values(by ='singers', ascending = False).head(10)
# Out:
#                                         name  \
# 69                                    Ibteda
# 28                                    Ibteda
# 1762                               Sathi Koi
# 446                       Woh Chaman Ki Sair
# 1989                              Jane Kiyun
# 71               Hum Mein Hi Thi Na Koi Baat
# 365                    Guzar Gaya Hai Zamana
# 1461                                End Part
# 1803                      Chopaye The Tailer
# 1955  Apne Baron Se Main Ne (From "Faisla" )
#
#                                                  singer  \
# 69    Chitra Singh,Gulzar,Naseeruddin Shah,Vinod Seh...
# 28    Chitra Singh,Gulzar,Naseeruddin Shah,Vinod Seh...
# 1762                Ali Abbas,Khalid Ghayur,Jamal Ghani
# 446        Ustad Ali Ahmed Hussain,Mohd. Hussain,Chorus
# 1989                Ali Abbas,Khalid Ghayur,Jamal Ghani
# 71    Chitra Singh,Jagjit Singh,Supported By Talents...
# 365        Ustad Ali Ahmed Hussain,Mohd. Hussain,Chorus
# ...

# %%
df = df[df['singers'] <=2]
df
# Out:
#                                                     name  \
# 0                                  Dil - E - Nadan Tujhe
# 1                      Agar Hum Kahen Aur Woh Muskara De
# 2                                          Unke Dekhe Se
# 3                Yeh Na Thi Hamari Qismat - Chitra Singh
# 4                                Hazaron Khwahishen Aisi
# ...                                                  ...
# 41350  Chaaridike Paaper Andhar (Manush Janam Diye Bi...
# 41351                                Ei Ki Go Shesh Daan
# 41352                                       Ei Je Bangla
# 41353                               Jatone Hridaye Rekho
# 41354                            Tomar Je Oi Haater Mala
#
#                                singer                            singer_id  \
# 0           Chitra Singh,Jagjit Singh         chitra-singh,jagjeet-singh-1
# 1           Chitra Singh,Jagjit Singh         chitra-singh,jagjeet-singh-1
# ...

# %%
df[df['singer'] == 'Jagjit Singh']['language'].unique()
# Out:
# array(['Urdu', 'Gujarati', 'Punjabi', 'Hindi'], dtype=object)

# %%
df.groupby('language')['duration'].mean().sort_values(ascending = False).head(10)
# Out:
# language
# Punjabi       450.034752
# Urdu          412.772445
# Bhojpuri      365.294000
# Haryanvi      320.653153
# Hindi         300.237332
# Rajasthani    291.889780
# Telugu        289.488093
# Marathi       281.094065
# Gujarati      267.705508
# Tamil         266.351171
# Name: duration, dtype: float64

# %%
singer_counts = df['singer_id'].str.split(',').explode().value_counts().sort_values(ascending =False).reset_index().head()
singer_counts.head()
# Out:
#                singer_id  count
# 0  s-p-balasubrahamanyam   3470
# 1            p-suseela-2   3077
# 2               s-janaki   2096
# 3          asha-bhosle-1   1845
# 4        lata-mangeshkar   1665

# %%
sum(df['singer'].str.split(',').explode() == 'Jagjit Singh')
# Out:
# 181

# %% [markdown]
# ### Award Show Questions

# %% [markdown]
# #### 1 - Which singer should be given the lifetime achievement award?
#
#
# - Answer_   s p balasubrahmanyam

# %%
df['singer_id'].str.split(',').explode().value_counts().sort_values(ascending =False).reset_index().head()
# Out:
#                singer_id  count
# 0  s-p-balasubrahamanyam   3470
# 1            p-suseela-2   3077
# 2               s-janaki   2096
# 3          asha-bhosle-1   1845
# 4        lata-mangeshkar   1665

# %% [markdown]
# #### 2- Which song has the longest duration and could be awarded the "Epic Song of the Year"?
# - Answer _ Haye Tumba

# %%
epic_song= df.sort_values(by = 'duration' , ascending = False).head(5)
epic_song
# Out:
#                                name          singer       singer_id  duration  \
# 16093                    Haye Tumba  Dilshad Akhtar  dilshad-akhtar     25680
# 16352                Bum Bum Lahiri  Dilshad Akhtar  dilshad-akhtar     24720
# 15000                Bum Bum Lahiri  Dilshad Akhtar  dilshad-akhtar     24720
# 15025          Kanu Atharu Bahoundi  Dilshad Akhtar  dilshad-akhtar     21840
# 14624  Desi Bandri Vilayati Cheekan  Dilshad Akhtar  dilshad-akhtar     21780
#
#                                  link language  singers
# 16093                      haye-tumba  Punjabi        1
# 16352                  bum-bum-lahiri  Punjabi        1
# 15000                bum-bum-lahiri-1  Punjabi        1
# 15025            kanu-atharu-bahoundi  Punjabi        1
# 14624  desi-bandri-vilayati-cheekan-1  Punjabi        1

# %% [markdown]
# #### 3- Which are the top 5 longest songs that could be nominated for the "Extended Play Excellence" award?

# %%
df.sort_values(by = 'duration' , ascending = False).head()
# Out:
#                                name          singer       singer_id  duration  \
# 16093                    Haye Tumba  Dilshad Akhtar  dilshad-akhtar     25680
# 16352                Bum Bum Lahiri  Dilshad Akhtar  dilshad-akhtar     24720
# 15000                Bum Bum Lahiri  Dilshad Akhtar  dilshad-akhtar     24720
# 15025          Kanu Atharu Bahoundi  Dilshad Akhtar  dilshad-akhtar     21840
# 14624  Desi Bandri Vilayati Cheekan  Dilshad Akhtar  dilshad-akhtar     21780
#
#                                  link language  singers
# 16093                      haye-tumba  Punjabi        1
# 16352                  bum-bum-lahiri  Punjabi        1
# 15000                bum-bum-lahiri-1  Punjabi        1
# 15025            kanu-atharu-bahoundi  Punjabi        1
# 14624  desi-bandri-vilayati-cheekan-1  Punjabi        1

# %% [markdown]
# #### 4- Which pairs of singers collaborate the most and could win the "Best Collaboration" award?
# - Answer _ S. P. Balasubrahmanyam,P. Susheela

# %%
singers_duet = df[df['singer'].str.contains(',')]
pair_counts = singers_duet.groupby('singer')['name'].count().reset_index(name='occurrences')
pair_counts = pair_counts.sort_values(by='occurrences', ascending=False)
pair_counts = pair_counts.head()

# %%
len(pair_counts)
# Out:
# 5

# %% [markdown]
# #### 5- What are the most common words in song titles, and how can this influence the naming of special categories?

# %%
df['name'].str.split(' ').explode().value_counts()
# Out:
# name
# Hai          1019
# -             988
# Na            949
# Re            826
# Ke            728
#              ...
# Dhashmesh       1
# Ungli           1
# Marsal          1
# Farkhe          1
# Rekho           1
# Name: count, Length: 35303, dtype: int64

# %% [markdown]
# ### Visualization

# %%
# Set the overall theme and palette
sns.set_theme(style="whitegrid")
palette = sns.color_palette("husl", 10)

fig, axes = plt.subplots(3, 2, figsize=(12, 18))

#Top 10 singers by number of songs
singer_df= singer_df.sort_values(by = 'count', ascending = False)
singer_df =singer_df.head(10)
sns.barplot(x ='singer' , y = 'count', data = singer_df,ax=axes[0,0],hue ='singer',dodge= False , palette = palette )
axes[0,0].set_title('Top 10 singers by number of songs', color = 'black')
axes[0,0].set_xlabel('Singers',color = 'black')
axes[0,0].set_ylabel('Number of songs', color = 'black')
axes[0, 0].tick_params(axis='x', rotation=90)


#Top 10 longest songs by duration
longest_songs = df.sort_values(by = 'duration' , ascending = False).head(10)
sns.barplot(x='name', y='duration', data= longest_songs,ax=axes[0,1],hue ='name',dodge= False ,palette = palette)
axes[0,1].set_title('Top 10 Longest Songs by Duration')
axes[0,1].set_xlabel('Songs name')
axes[0,1].set_ylabel('Duration')
axes[0, 1].tick_params(axis='x', rotation=90)


#Punjabi songs by duration 3 to 4 mins
punjabi_songs = df[(df['language'] == 'Punjabi') & (df['duration']>=180) & (df['duration'] <=240)].head(10)
sns.barplot(x='name',y= 'duration', data=punjabi_songs,ax=axes[1,0],hue ='name',dodge= False,palette = palette)
axes[1,0].set_title('Punjabi Songs with Duration 3 to 4 Minutes')
axes[1,0].set_xlabel('Name')
axes[1,0].set_ylabel('Duration')
axes[1, 0].tick_params(axis='x', rotation=90)

#Top singer
sns.lineplot(data = singer_df , x= 'singer', y= 'count',ax=axes[1,1],marker='o',color='b',palette = palette)
axes[1,1].set_title('Top singer')
axes[1,1].set_xlabel('Singer')
axes[1,1].set_ylabel('number of songs')
axes[1,1].tick_params(axis='x', rotation=90)


#Epic song of the year
epic_song= df.sort_values(by = 'duration' , ascending = False).head(5)
sns.barplot(data = epic_song , x='name', y= 'duration',ax=axes[2,0],hue ='name',dodge= False ,palette = palette)
axes[2,0].set_title('Epic song of the year')
axes[2,0].set_xlabel('Songs')
axes[2,0].set_ylabel('Duration')
axes[2,0].tick_params(axis='x', rotation=90)


#Best collaboration
pair_counts = pair_counts.head()
sns.barplot(x='singer' , y= 'occurrences',data = pair_counts , ax=axes[2,1],hue ='singer',dodge= False,palette = palette)
axes[2,1].set_title('Best Collaboration')
axes[2,1].set_xlabel('Singers collab')
axes[2,1].set_ylabel('Occurrences')
axes[2,1].tick_params(axis='x', rotation=90)

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-70-29f6daa0466d>:19: UserWarning: The palette list has more values (10) than needed (7), which may not be intended.
#   sns.barplot(x='name', y='duration', data= longest_songs,ax=axes[0,1],hue ='name',dodge= False ,palette = palette)
# <ipython-input-70-29f6daa0466d>:35: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data = singer_df , x= 'singer', y= 'count',ax=axes[1,1],marker='o',color='b',palette = palette)
# <ipython-input-70-29f6daa0466d>:44: UserWarning: The palette list has more values (10) than needed (4), which may not be intended.
#   sns.barplot(data = epic_song , x='name', y= 'duration',ax=axes[2,0],hue ='name',dodge= False ,palette = palette)
# <ipython-input-70-29f6daa0466d>:53: UserWarning: The palette list has more values (10) than needed (5), which may not be intended.
#   sns.barplot(x='singer' , y= 'occurrences',data = pair_counts , ax=axes[2,1],hue ='singer',dodge= False,palette = palette)
